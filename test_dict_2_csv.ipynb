# %%
import csv

data = [
    {
        'Locality': 'Froidchapelle',
        'Type of property': 'house',
        'Subtype of property': 'chalet',
        'Price': 100000,
        'Type of sale': 'Normal sale',
        'Number of rooms': 2,
        'Living Area': 50,
        'Terrace Area': 6,
        'Garden Area': 250,
        'Surface of the land': 250,
        'Number of facades': 4,
        'State of the building': 'Excellent',
        'Furnished': 0,
        'Terrace': 1,
        'Garden': 1,
        'Swimming pool': 0
    }
]

file_name = "real_estate_data.csv"

columns = list(data[0].keys())

file = open(file_name, "w", newline="", encoding="utf-8")

writer = csv.DictWriter(file, columns)

writer.writeheader()

for row in data:
    writer.writerow(row)

file.close()

print("CSV file created")
# Out:
# CSV file created

# %%
import csv

data = [
    {'Locality': 'Froidchapelle', 'Type of property': 'house', 'Subtype of property': 'chalet', 'Price': 100000, 'Type of sale': 'Normal sale', 'Number of rooms': 2, 'Living Area': 50, 'Terrace Area': 6, 'Garden Area': 250, 'Surface of the land': 250, 'Number of facades': 4, 'State of the building': 'Excellent', 'Furnished': 0, 'Terrace': 1, 'Garden': 1, 'Swimming pool': 0},
    {'Locality': 'Moorslede', 'Type of property': 'house', 'Subtype of property': 'residence', 'Price': 80000, 'Type of sale': 'Normal sale', 'Number of rooms': 4, 'Living Area': 134, 'Terrace Area': None, 'Garden Area': None, 'Surface of the land': 126, 'Number of facades': 2, 'State of the building': None, 'Furnished': 0, 'Terrace': 1, 'Garden': 1, 'Swimming pool': 0},
    {'Locality': 'Montignies-sur-Sambre', 'Type of property': 'house', 'Subtype of property': 'residence', 'Price': 89000, 'Type of sale': 'Normal sale', 'Number of rooms': 2, 'Living Area': 84, 'Terrace Area': None, 'Garden Area': None, 'Surface of the land': 345, 'Number of facades': 3, 'State of the building': 'To be renovated', 'Furnished': 0, 'Terrace': 0, 'Garden': 1, 'Swimming pool': 0},
    {'Locality': 'Erquelinnes', 'Type of property': 'house', 'Subtype of property': 'residence', 'Price': 90000, 'Type of sale': 'Normal sale', 'Number of rooms': 3, 'Living Area': 136, 'Terrace Area': None, 'Garden Area': None, 'Surface of the land': 350, 'Number of facades': None, 'State of the building': 'To be renovated', 'Furnished': 0, 'Terrace': 1, 'Garden': 1, 'Swimming pool': 0},
    {'Locality': 'Marchienne-au-Pont', 'Type of property': 'house', 'Subtype of property': 'residence', 'Price': 79000, 'Type of sale': 'Normal sale', 'Number of rooms': 2, 'Living Area': 230, 'Terrace Area': None, 'Garden Area': None, 'Surface of the land': 79, 'Number of facades': 2, 'State of the building': 'To be renovated', 'Furnished': 0, 'Terrace': 0, 'Garden': 1, 'Swimming pool': 0}
]

file_name = "real_estate_data.csv"

columns = list(data[0].keys())

file = open(file_name, "w", newline="", encoding="utf-8")

writer = csv.DictWriter(file, columns)

writer.writeheader()

for row in data:
    writer.writerow(row)

file.close()

print("CSV file created - File Name:",file_name)
# Out:
# CSV file created - File Name: real_estate_data.csv
